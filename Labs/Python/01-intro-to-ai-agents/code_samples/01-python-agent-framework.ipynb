# %% [markdown]
# # 🐍 AI Travel Agent with Microsoft Agent Framework (Python)
#
# ## 📋 Scenario Overview
#
# This notebook demonstrates how to build an intelligent travel planning agent using the Microsoft Agent Framework for Python. The agent leverages Azure AI Foundry to automatically generate personalized day-trip itineraries for random destinations worldwide.
#
# **Key Features:**
# - 🎲 **Smart Destination Selection**: Custom tool function for random destination picking
# - 🗺️ **Detailed Itinerary Generation**: AI-powered travel planning with local recommendations
# - 🔄 **Async Processing**: Uses asyncio for efficient API communication
# - 🛠️ **Tool Integration**: Demonstrates function calling capabilities in AI agents
#
# ## 🏗️ Technical Implementation
#
# ### Core Components
# - **Agent Framework**: Python implementation of Microsoft's agent orchestration system
# - **Azure AI Foundry**: Access to state-of-the-art language models via Azure's AI platform
# - **OpenAI Compatibility**: Uses OpenAI client patterns with Azure AI Foundry backend
# - **Environment Management**: Secure credential handling with python-dotenv
#
# ### Architecture Flow
# ```python
# User Request → ChatAgent → Azure AI Foundry API ↔ get_random_destination()
#                      ↓
#               Travel Itinerary Response
# ```
#
# ### Key Classes & Methods
# - `ChatAgent`: Main conversational agent orchestrator
# - `OpenAIChatClient`: Azure AI Foundry API client wrapper
# - `get_random_destination()`: Custom tool function for destination selection
# - Environment variables: Secure API configuration management
#
# ## ⚙️ Prerequisites & Setup
#
# **Required Dependencies:**
# ```bash
#
# pip install agent-framework-core -U
# ```
#
# **Environment Configuration (.env file):**
# ```env
# AZURE_AI_FOUNDRY_ENDPOINT=https://your-ai-foundry-endpoint.eastus.inference.ai.azure.com
# AZURE_AI_FOUNDRY_API_KEY=your_azure_ai_foundry_api_key
# AZURE_AI_FOUNDRY_MODEL_ID=gpt-4o-mini
# ```
#
# **Azure AI Foundry Access:**
# 1. Create an Azure AI Foundry resource in Azure portal
# 2. Get the endpoint URL and API key from the resource
# 3. Configure environment variables as shown above
#
# ## 🚀 Usage Instructions
#
# Execute the cells below in sequence to:
# 1. Import required libraries and load environment variables
# 2. Define the random destination generator tool
# 3. Create and configure the AI agent
# 4. Run travel planning requests and view results
#
# Let's build an intelligent travel planning assistant! 🌟

# %%
! pip install agent-framework-core -U
# Out:
# Collecting agent-framework-core
#   Downloading agent_framework_core-1.0.0b251016-py3-none-any.whl.metadata (9.5 kB)
# Collecting openai<2,>=1.99.0 (from agent-framework-core)
#   Using cached openai-1.109.1-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: pydantic<3,>=2 in c:\adobe\.venv\lib\site-packages (from agent-framework-core) (2.10.6)
# Requirement already satisfied: pydantic-settings<3,>=2 in c:\adobe\.venv\lib\site-packages (from agent-framework-core) (2.11.0)
# Requirement already satisfied: typing-extensions in c:\adobe\.venv\lib\site-packages (from agent-framework-core) (4.15.0)
# Requirement already satisfied: opentelemetry-api>=1.24 in c:\adobe\.venv\lib\site-packages (from agent-framework-core) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.24 in c:\adobe\.venv\lib\site-packages (from agent-framework-core) (1.38.0)
# Collecting mcp>=1.13 (from mcp[ws]>=1.13->agent-framework-core)
#   Using cached mcp-1.19.0-py3-none-any.whl.metadata (85 kB)
# Requirement already satisfied: azure-monitor-opentelemetry>=1.7.0 in c:\adobe\.venv\lib\site-packages (from agent-framework-core) (1.8.1)
# Requirement already satisfied: azure-monitor-opentelemetry-exporter>=1.0.0b41 in c:\adobe\.venv\lib\site-packages (from agent-framework-core) (1.0.0b44)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.36.0 (from agent-framework-core)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.38.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-semantic-conventions-ai>=0.4.13 (from agent-framework-core)
#   Downloading opentelemetry_semantic_conventions_ai-0.4.13-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: aiofiles>=24.1.0 in c:\adobe\.venv\lib\site-packages (from agent-framework-core) (25.1.0)
# Requirement already satisfied: azure-identity<2,>=1 in c:\adobe\.venv\lib\site-packages (from agent-framework-core) (1.19.0)
# Requirement already satisfied: azure-core>=1.31.0 in c:\adobe\.venv\lib\site-packages (from azure-identity<2,>=1->agent-framework-core) (1.32.0)
# Requirement already satisfied: cryptography>=2.5 in c:\adobe\.venv\lib\site-packages (from azure-identity<2,>=1->agent-framework-core) (44.0.0)
# Requirement already satisfied: msal>=1.30.0 in c:\adobe\.venv\lib\site-packages (from azure-identity<2,>=1->agent-framework-core) (1.31.1)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\adobe\.venv\lib\site-packages (from azure-identity<2,>=1->agent-framework-core) (1.2.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\adobe\.venv\lib\site-packages (from openai<2,>=1.99.0->agent-framework-core) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\adobe\.venv\lib\site-packages (from openai<2,>=1.99.0->agent-framework-core) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\adobe\.venv\lib\site-packages (from openai<2,>=1.99.0->agent-framework-core) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\adobe\.venv\lib\site-packages (from openai<2,>=1.99.0->agent-framework-core) (0.8.2)
# Requirement already satisfied: sniffio in c:\adobe\.venv\lib\site-packages (from openai<2,>=1.99.0->agent-framework-core) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\adobe\.venv\lib\site-packages (from openai<2,>=1.99.0->agent-framework-core) (4.67.1)
# Requirement already satisfied: idna>=2.8 in c:\adobe\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai<2,>=1.99.0->agent-framework-core) (3.10)
# Requirement already satisfied: certifi in c:\adobe\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai<2,>=1.99.0->agent-framework-core) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\adobe\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai<2,>=1.99.0->agent-framework-core) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\adobe\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2,>=1.99.0->agent-framework-core) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\adobe\.venv\lib\site-packages (from pydantic<3,>=2->agent-framework-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\adobe\.venv\lib\site-packages (from pydantic<3,>=2->agent-framework-core) (2.27.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\adobe\.venv\lib\site-packages (from pydantic-settings<3,>=2->agent-framework-core) (1.0.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\adobe\.venv\lib\site-packages (from pydantic-settings<3,>=2->agent-framework-core) (0.4.2)
# Requirement already satisfied: requests>=2.21.0 in c:\adobe\.venv\lib\site-packages (from azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in c:\adobe\.venv\lib\site-packages (from azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (1.17.0)
# Requirement already satisfied: azure-core-tracing-opentelemetry~=1.0.0b11 in c:\adobe\.venv\lib\site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (1.0.0b12)
# Requirement already satisfied: opentelemetry-instrumentation-django~=0.57b0 in c:\adobe\.venv\lib\site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.59b0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi~=0.57b0 in c:\adobe\.venv\lib\site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.59b0)
# Requirement already satisfied: opentelemetry-instrumentation-flask~=0.57b0 in c:\adobe\.venv\lib\site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.59b0)
# Requirement already satisfied: opentelemetry-instrumentation-psycopg2~=0.57b0 in c:\adobe\.venv\lib\site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.59b0)
# Requirement already satisfied: opentelemetry-instrumentation-requests~=0.57b0 in c:\adobe\.venv\lib\site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.59b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib~=0.57b0 in c:\adobe\.venv\lib\site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.59b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib3~=0.57b0 in c:\adobe\.venv\lib\site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.59b0)
# Requirement already satisfied: opentelemetry-resource-detector-azure~=0.1.5 in c:\adobe\.venv\lib\site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.1.5)
# Requirement already satisfied: fixedint==0.1.6 in c:\adobe\.venv\lib\site-packages (from azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core) (0.1.6)
# Requirement already satisfied: msrest>=0.6.10 in c:\adobe\.venv\lib\site-packages (from azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core) (0.7.1)
# Requirement already satisfied: psutil<8,>=5.9 in c:\adobe\.venv\lib\site-packages (from azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core) (7.1.2)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\adobe\.venv\lib\site-packages (from opentelemetry-api>=1.24->agent-framework-core) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\adobe\.venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.24->agent-framework-core) (3.23.0)
# Requirement already satisfied: opentelemetry-instrumentation-wsgi==0.59b0 in c:\adobe\.venv\lib\site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.59b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.59b0 in c:\adobe\.venv\lib\site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.59b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in c:\adobe\.venv\lib\site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.59b0)
# Requirement already satisfied: opentelemetry-util-http==0.59b0 in c:\adobe\.venv\lib\site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.59b0)
# Requirement already satisfied: packaging>=18.0 in c:\adobe\.venv\lib\site-packages (from opentelemetry-instrumentation==0.59b0->opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (24.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\adobe\.venv\lib\site-packages (from opentelemetry-instrumentation==0.59b0->opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (1.17.3)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.59b0 in c:\adobe\.venv\lib\site-packages (from opentelemetry-instrumentation-fastapi~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.59b0)
# Requirement already satisfied: asgiref~=3.0 in c:\adobe\.venv\lib\site-packages (from opentelemetry-instrumentation-asgi==0.59b0->opentelemetry-instrumentation-fastapi~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (3.10.0)
# Requirement already satisfied: opentelemetry-instrumentation-dbapi==0.59b0 in c:\adobe\.venv\lib\site-packages (from opentelemetry-instrumentation-psycopg2~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core) (0.59b0)
# Requirement already satisfied: cffi>=1.12 in c:\adobe\.venv\lib\site-packages (from cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (1.17.1)
# Requirement already satisfied: pycparser in c:\adobe\.venv\lib\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (2.22)
# Requirement already satisfied: httpx-sse>=0.4 in c:\adobe\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\adobe\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (4.25.1)
# Collecting pydantic<3,>=2 (from agent-framework-core)
#   Downloading pydantic-2.12.3-py3-none-any.whl.metadata (87 kB)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\adobe\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.0.20)
# Requirement already satisfied: pywin32>=310 in c:\adobe\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\adobe\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (3.0.2)
# Requirement already satisfied: starlette>=0.27 in c:\adobe\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.45.3)
# Requirement already satisfied: uvicorn>=0.31.1 in c:\adobe\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.34.0)
# Collecting pydantic-core==2.41.4 (from pydantic<3,>=2->agent-framework-core)
#   Downloading pydantic_core-2.41.4-cp313-cp313-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: attrs>=22.2.0 in c:\adobe\.venv\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\adobe\.venv\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\adobe\.venv\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\adobe\.venv\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.28.0)
# Collecting websockets>=15.0.1 (from mcp[ws]>=1.13->agent-framework-core)
#   Downloading websockets-15.0.1-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\adobe\.venv\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity<2,>=1->agent-framework-core) (2.10.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\adobe\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\adobe\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.3.0)
# Requirement already satisfied: portalocker<3,>=1.4 in c:\adobe\.venv\lib\site-packages (from msal-extensions>=1.2.0->azure-identity<2,>=1->agent-framework-core) (2.10.1)
# Requirement already satisfied: isodate>=0.6.0 in c:\adobe\.venv\lib\site-packages (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core) (0.7.2)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\adobe\.venv\lib\site-packages (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core) (2.0.0)
# Collecting googleapis-common-protos~=1.57 (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core)
#   Downloading googleapis_common_protos-1.71.0-py3-none-any.whl.metadata (9.4 kB)
# Collecting grpcio<2.0.0,>=1.66.2 (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core)
#   Downloading grpcio-1.76.0-cp313-cp313-win_amd64.whl.metadata (3.8 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.38.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.38.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.38.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core)
#   Downloading opentelemetry_proto-1.38.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting protobuf<7.0,>=5.0 (from opentelemetry-proto==1.38.0->opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core)
#   Using cached protobuf-6.33.0-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\adobe\.venv\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core) (3.3.1)
# Requirement already satisfied: colorama in c:\adobe\.venv\lib\site-packages (from tqdm>4->openai<2,>=1.99.0->agent-framework-core) (0.4.6)
# Requirement already satisfied: click>=7.0 in c:\adobe\.venv\lib\site-packages (from uvicorn>=0.31.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (8.1.8)
# Downloading agent_framework_core-1.0.0b251016-py3-none-any.whl (268 kB)
# Using cached openai-1.109.1-py3-none-any.whl (948 kB)
# Downloading mcp-1.19.0-py3-none-any.whl (170 kB)
# Downloading pydantic-2.12.3-py3-none-any.whl (462 kB)
# Downloading pydantic_core-2.41.4-cp313-cp313-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 19.3 MB/s  0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.38.0-py3-none-any.whl (19 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.38.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.38.0-py3-none-any.whl (72 kB)
# Downloading googleapis_common_protos-1.71.0-py3-none-any.whl (294 kB)
# Downloading grpcio-1.76.0-cp313-cp313-win_amd64.whl (4.7 MB)
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ------------------------------------- -- 4.5/4.7 MB 24.8 MB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 20.4 MB/s  0:00:00
# Downloading protobuf-6.33.0-cp310-abi3-win_amd64.whl (436 kB)
# Downloading opentelemetry_semantic_conventions_ai-0.4.13-py3-none-any.whl (6.1 kB)
# Downloading websockets-15.0.1-cp313-cp313-win_amd64.whl (176 kB)
# Installing collected packages: websockets, pydantic-core, protobuf, opentelemetry-semantic-conventions-ai, grpcio, pydantic, opentelemetry-proto, googleapis-common-protos, opentelemetry-exporter-otlp-proto-common, openai, mcp, opentelemetry-exporter-otlp-proto-grpc, agent-framework-core
#
#   Attempting uninstall: websockets
#
#     Found existing installation: websockets 14.2
#
#     Uninstalling websockets-14.2:
#
#       Successfully uninstalled websockets-14.2
#
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#   Attempting uninstall: pydantic-core
#    ----------------------------------------  0/13 [websockets]
#    --- ------------------------------------  1/13 [pydantic-core]
#     Found existing installation: pydantic_core 2.27.2
#    --- ------------------------------------  1/13 [pydantic-core]
#     Uninstalling pydantic_core-2.27.2:
#    --- ------------------------------------  1/13 [pydantic-core]
#       Successfully uninstalled pydantic_core-2.27.2
#    --- ------------------------------------  1/13 [pydantic-core]
#    --- ------------------------------------  1/13 [pydantic-core]
#    --- ------------------------------------  1/13 [pydantic-core]
#   Attempting uninstall: protobuf
#    --- ------------------------------------  1/13 [pydantic-core]
#     Found existing installation: protobuf 4.25.8
#    --- ------------------------------------  1/13 [pydantic-core]
#    ------ ---------------------------------  2/13 [protobuf]
#     Uninstalling protobuf-4.25.8:
#    ------ ---------------------------------  2/13 [protobuf]
#       Successfully uninstalled protobuf-4.25.8
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ -----------------------  3/13 [opentelemetry-semantic-conventions-ai]
#    ------------ ---------------------------  4/13 [grpcio]
#    ------------ ---------------------------  4/13 [grpcio]
#    ------------ ---------------------------  4/13 [grpcio]
#    ------------ ---------------------------  4/13 [grpcio]
#    ------------ ---------------------------  4/13 [grpcio]
#    ------------ ---------------------------  4/13 [grpcio]
#    ------------ ---------------------------  4/13 [grpcio]
#    ------------ ---------------------------  4/13 [grpcio]
#    ------------ ---------------------------  4/13 [grpcio]
#    ------------ ---------------------------  4/13 [grpcio]
#    ------------ ---------------------------  4/13 [grpcio]
#    ------------ ---------------------------  4/13 [grpcio]
#    ------------ ---------------------------  4/13 [grpcio]
#    ------------ ---------------------------  4/13 [grpcio]
#    ------------ ---------------------------  4/13 [grpcio]
#    ------------ ---------------------------  4/13 [grpcio]
#    ------------ ---------------------------  4/13 [grpcio]
#    ------------ ---------------------------  4/13 [grpcio]
#    ------------ ---------------------------  4/13 [grpcio]
#   Attempting uninstall: pydantic
#    ------------ ---------------------------  4/13 [grpcio]
#    --------------- ------------------------  5/13 [pydantic]
#     Found existing installation: pydantic 2.10.6
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#     Uninstalling pydantic-2.10.6:
#    --------------- ------------------------  5/13 [pydantic]
#       Successfully uninstalled pydantic-2.10.6
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    --------------- ------------------------  5/13 [pydantic]
#    ------------------ ---------------------  6/13 [opentelemetry-proto]
#    ------------------ ---------------------  6/13 [opentelemetry-proto]
#    ------------------ ---------------------  6/13 [opentelemetry-proto]
#    ------------------ ---------------------  6/13 [opentelemetry-proto]
#    ------------------ ---------------------  6/13 [opentelemetry-proto]
#    ------------------ ---------------------  6/13 [opentelemetry-proto]
#    ------------------ ---------------------  6/13 [opentelemetry-proto]
#    ------------------ ---------------------  6/13 [opentelemetry-proto]
#    ------------------ ---------------------  6/13 [opentelemetry-proto]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    --------------------- ------------------  7/13 [googleapis-common-protos]
#    ---------------- ----------  8/13 [opentelemetry-exporter-otlp-proto-common]
#    ---------------- ----------  8/13 [opentelemetry-exporter-otlp-proto-common]
#    ---------------- ----------  8/13 [opentelemetry-exporter-otlp-proto-common]
#   Attempting uninstall: openai
#    ---------------- ----------  8/13 [opentelemetry-exporter-otlp-proto-common]
#    --------------------------- ------------  9/13 [openai]
#     Found existing installation: openai 1.67.0
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#     Uninstalling openai-1.67.0:
#    --------------------------- ------------  9/13 [openai]
#       Successfully uninstalled openai-1.67.0
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#    --------------------------- ------------  9/13 [openai]
#   Attempting uninstall: mcp
#    --------------------------- ------------  9/13 [openai]
#    ------------------------------ --------- 10/13 [mcp]
#     Found existing installation: mcp 1.12.4
#    ------------------------------ --------- 10/13 [mcp]
#     Uninstalling mcp-1.12.4:
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#       Successfully uninstalled mcp-1.12.4
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------------ --------- 10/13 [mcp]
#    ------------------------ ---- 11/13 [opentelemetry-exporter-otlp-proto-grpc]
#    ------------------------ ---- 11/13 [opentelemetry-exporter-otlp-proto-grpc]
#    ------------------------------------ --- 12/13 [agent-framework-core]
#    ------------------------------------ --- 12/13 [agent-framework-core]
#    ------------------------------------ --- 12/13 [agent-framework-core]
#    ------------------------------------ --- 12/13 [agent-framework-core]
#    ------------------------------------ --- 12/13 [agent-framework-core]
#    ------------------------------------ --- 12/13 [agent-framework-core]
#    ------------------------------------ --- 12/13 [agent-framework-core]
#    ------------------------------------ --- 12/13 [agent-framework-core]
#    ------------------------------------ --- 12/13 [agent-framework-core]
#    ------------------------------------ --- 12/13 [agent-framework-core]
#    ------------------------------------ --- 12/13 [agent-framework-core]
#    ------------------------------------ --- 12/13 [agent-framework-core]
#    ------------------------------------ --- 12/13 [agent-framework-core]
#    ------------------------------------ --- 12/13 [agent-framework-core]
#    ------------------------------------ --- 12/13 [agent-framework-core]
#    ------------------------------------ --- 12/13 [agent-framework-core]
#    ------------------------------------ --- 12/13 [agent-framework-core]
#    ------------------------------------ --- 12/13 [agent-framework-core]
#    ------------------------------------ --- 12/13 [agent-framework-core]
#    ------------------------------------ --- 12/13 [agent-framework-core]
#    ------------------------------------ --- 12/13 [agent-framework-core]
#    ------------------------------------ --- 12/13 [agent-framework-core]
#    ------------------------------------ --- 12/13 [agent-framework-core]
#    ---------------------------------------- 13/13 [agent-framework-core]
#
# Successfully installed agent-framework-core-1.0.0b251016 googleapis-common-protos-1.71.0 grpcio-1.76.0 mcp-1.19.0 openai-1.109.1 opentelemetry-exporter-otlp-proto-common-1.38.0 opentelemetry-exporter-otlp-proto-grpc-1.38.0 opentelemetry-proto-1.38.0 opentelemetry-semantic-conventions-ai-0.4.13 protobuf-6.33.0 pydantic-2.12.3 pydantic-core-2.41.4 websockets-15.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogen-core 0.4.4 requires protobuf~=4.25.1, but you have protobuf 6.33.0 which is incompatible.
# semantic-kernel 1.31.0 requires pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0, but you have pydantic 2.12.3 which is incompatible.

# %%
# 📦 Import Required Libraries
# Standard library imports for system operations and random number generation
import os
from random import randint

# Third-party library for loading environment variables from .env file
from dotenv import load_dotenv

# %%
# 🤖 Import Microsoft Agent Framework Components
# ChatAgent: The main agent class for conversational AI
# OpenAIChatClient: Client for connecting to OpenAI-compatible APIs (including GitHub Models)
from agent_framework import ChatAgent
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Load Environment Variables
# This loads configuration from a .env file in the project root
# Required variables: AZURE_AI_FOUNDRY_ENDPOINT, AZURE_AI_FOUNDRY_API_KEY, AZURE_AI_FOUNDRY_MODEL_ID
load_dotenv()

# %%
# 🎲 Tool Function: Random Destination Generator
# This function will be available to the agent as a tool
# The agent can call this function to get random vacation destinations
def get_random_destination() -> str:
    """Get a random vacation destination.
    
    Returns:
        str: A randomly selected destination from our predefined list
    """
    # List of popular vacation destinations around the world
    destinations = [
        "Barcelona, Spain",
        "Paris, France", 
        "Berlin, Germany",
        "Tokyo, Japan",
        "Sydney, Australia",
        "New York, USA",
        "Cairo, Egypt",
        "Cape Town, South Africa",
        "Rio de Janeiro, Brazil",
        "Bali, Indonesia"
    ]
    # Return a random destination from the list
    return destinations[randint(0, len(destinations) - 1)]

# %%
# 🔗 Create OpenAI Chat Client for Azure AI Foundry
# This client connects to Azure AI Foundry API (OpenAI-compatible endpoint)
# Environment variables required:
# - AZURE_AI_FOUNDRY_ENDPOINT: API endpoint URL from your Azure AI Foundry resource
# - AZURE_AI_FOUNDRY_API_KEY: Your Azure AI Foundry API key
# - AZURE_AI_FOUNDRY_MODEL_ID: Model to use (e.g., gpt-4o-mini, gpt-4o)
openai_chat_client = OpenAIChatClient(
    base_url=os.environ.get("AZURE_AI_FOUNDRY_ENDPOINT"),
    api_key=os.environ.get("AZURE_AI_FOUNDRY_API_KEY"), 
    model_id=os.environ.get("AZURE_AI_FOUNDRY_MODEL_ID")
)

# %%
# 🤖 Create the Travel Planning Agent
# This creates a conversational AI agent with specific capabilities:
# - chat_client: The AI model client for generating responses
# - instructions: System prompt that defines the agent's personality and role
# - tools: List of functions the agent can call to perform actions
agent = ChatAgent(
    chat_client=openai_chat_client,
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations.",
    tools=[get_random_destination]  # Our random destination tool function
)

# %%
# 🚀 Run the Agent
# Send a message to the agent and get a response
# The agent will use its tools (get_random_destination) if needed
response = await agent.run("Plan me a day trip")

# %%
# 📋 View Raw Response Object
# This shows the complete response structure including metadata
# Useful for debugging and understanding the response format
response

# %%
# 📖 Extract and Display the Travel Plan
# Get the last message from the conversation (agent's response)s
last_message = response.messages[-1]
# Extract the text content from the message
text_content = last_message.contents[0].text
# Display the formatted travel plan
print("🏖️ Travel plan:")
print(text_content)
